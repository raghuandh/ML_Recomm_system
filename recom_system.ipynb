# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/mirya/OneDrive/Desktop/recommendation_system/TeluguMovies_dataset.csv")
data.head(5)
# Out:
#    Unnamed: 0                        Movie    Year Certificate
# 0           0      Bahubali: The Beginning  2015.0          UA  \
# 1           1  Baahubali 2: The Conclusion  2017.0          UA
# 2           2              1 - Nenokkadine  2014.0          UA
# 3           3                      Dhoom:3  2013.0          UA
# 4           4                       Ra.One  2011.0           U
#
#                                    Genre
# 0              Action, Drama              \
# 1              Action, Drama
# 2           Action, Thriller
# 3           Action, Thriller
# 4  Action, Adventure, Sci-Fi
#
#                                             Overview  Runtime  Rating
# 0      In ancient India, an adventurous and darin...      159     8.1  \
# 1      When Shiva, the son of Bahubali, learns ab...      167     8.2
# 2      A rock star must overcome his psychologica...      170     8.1
# 3      When Sahir, a circus entertainer trained i...      172     5.4
# 4      When the titular antagonist of an action g...      156     4.6
#
#    No.of.Ratings
# 0          99114
# 1          71458
# 2          42372
# 3          42112
# 4          37211

# %%
data['Overview'].head()
# Out:
# 0        In ancient India, an adventurous and darin...
# 1        When Shiva, the son of Bahubali, learns ab...
# 2        A rock star must overcome his psychologica...
# 3        When Sahir, a circus entertainer trained i...
# 4        When the titular antagonist of an action g...
# Name: Overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words = 'english')
data['Overview'] = data['Overview'].fillna('')
tfidf_matrix = tfidf.fit_transform(data['Overview'])
tfidf_matrix.shape
# Out:
# (1400, 5206)

# %%
tfidf_matrix
# Out:
# <1400x5206 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16368 stored elements in Compressed Sparse Row format>

# %%
list(tfidf_matrix)
# Out:
# [<1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
# ...
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 0 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <1x5206 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  ...]

# %%
#Array mapping from feature integer indices to feature name.
tfidf.get_feature_names_out()[50:100]
# Out:
# array(['34', '365', '40', '40s', '45', '48', '50', '50s', '60', '600',
#        '60s', '80s', '8th', '900', 'aadhi', 'aadi', 'aamani', 'abandoned',
#        'abandons', 'abbas', 'abbasi', 'abduct', 'abducted', 'abhay',
#        'abhi', 'abhimanyu', 'abhiram', 'abhishek', 'abides', 'abiding',
#        'ability', 'able', 'abortion', 'abraham', 'abroad', 'absorbed',
#        'abuse', 'academics', 'accept', 'accepting', 'accepts',
#        'accessible', 'accident', 'accidental', 'accidentally',
#        'accompanied', 'accompany', 'according', 'account', 'accountent'],
#       dtype=object)

# %%
# using cosine similarity to calculate numeric quantity that denotes similarity 
# between two movies
# you have tfidf vectors the dot product between each vector gives directly\
# cosine similarity score 
# using linear_kernel() function instead of cosine_similarites() since it is faster

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (1400, 1400)

# %%
cosine_sim[1]
# Out:
# array([0.        , 1.        , 0.        , ..., 0.        , 0.03445427,
#        0.04135381])

# %%
# takes movie title as input and outputs a list of 10 similar movies\
# #you need a mechanism to identify index of movie in dataframe by giving title

# %%
indices = pd.Series(data.index, index = data['Movie']).drop_duplicates()
indices
# Out:
# Movie
# Bahubali: The Beginning           0
# Baahubali 2: The Conclusion       1
# 1 - Nenokkadine                   2
# Dhoom:3                           3
# Ra.One                            4
#                                ...
# Maro Monagadu                  1395
# Jakkanna                       1396
# Muvva Gopaludu                 1397
# Ninney Ishta Paddaanu          1398
# 9 Nelalu                       1399
# Length: 1400, dtype: int64

# %%
def get_recommendations(Movie, cosine_sim = cosine_sim2):
    #Get the index of movie that matches the title
    index = indices[Movie]
    
    #get the pairwise simlarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[index]))
    
    #sort movies based on similarity score
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)
    
    #get scores of top 10 similar movies
    sim_scores = sim_scores[1:11]
    
    #get movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    #return top 10 similar movies
    return data['Movie'].iloc[movie_indices]

# %%
get_recommendations('1 - Nenokkadine')
# Out:
# 912                 Mugguru Monagallu
# 319     Uu Kodathara Ulikki Padathara
# 558                           Mesthri
# 801                    Srimannarayana
# 570                           Keshava
# 561                  Yuddham Sharanam
# 238                             Rebel
# 1045                   Muthyala Muggu
# 815               Preminchukundam Raa
# 1151            Chettaniki Kallu Levu
# Name: Movie, dtype: object

# %%
data[['Movie','Overview','Genre']].head()
# Out:
#                          Movie
# 0      Bahubali: The Beginning  \
# 1  Baahubali 2: The Conclusion
# 2              1 - Nenokkadine
# 3                      Dhoom:3
# 4                       Ra.One
#
#                                             Overview
# 0      In ancient India, an adventurous and darin...  \
# 1      When Shiva, the son of Bahubali, learns ab...
# 2      A rock star must overcome his psychologica...
# 3      When Sahir, a circus entertainer trained i...
# 4      When the titular antagonist of an action g...
#
#                                    Genre
# 0              Action, Drama
# 1              Action, Drama
# 2           Action, Thriller
# 3           Action, Thriller
# 4  Action, Adventure, Sci-Fi

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ","")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ",""))
        else:
            return ''

# %%
features = ['Movie','Overview','Genre']
for feature in features:
    data[feature] = data[feature].apply(clean_data)

# %%
def create_soup(x):
    return x['Movie'] + ' ' + x['Overview'] + ' ' + x['Genre']

# %%
data['soup'] = data.apply(create_soup,axis=1)

# %%
data[['soup']].head()
# Out:
#                                                 soup
# 0  bahubali:thebeginning inancientindia,anadventu...
# 1  baahubali2:theconclusion whenshiva,thesonofbah...
# 2  1-nenokkadine arockstarmustovercomehispsycholo...
# 3  dhoom:3 whensahir,acircusentertainertrainedinm...
# 4  ra.one whenthetitularantagonistofanactiongamet...

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(data['soup'])

# %%
count_matrix.shape
# Out:
# (1400, 5434)

# %%
data.head()
# Out:
#    level_0  index  Unnamed: 0                     Movie    Year Certificate
# 0        0      0           0     bahubali:thebeginning  2015.0          UA  \
# 1        1      1           1  baahubali2:theconclusion  2017.0          UA
# 2        2      2           2             1-nenokkadine  2014.0          UA
# 3        3      3           3                   dhoom:3  2013.0          UA
# 4        4      4           4                    ra.one  2011.0           U
#
#                      Genre                                           Overview
# 0             action,drama  inancientindia,anadventurousanddaringmanbecome...  \
# 1             action,drama  whenshiva,thesonofbahubali,learnsabouthisherit...
# 2          action,thriller  arockstarmustovercomehispsychologicalinhibitio...
# 3          action,thriller  whensahir,acircusentertainertrainedinmagicanda...
# 4  action,adventure,sci-fi  whenthetitularantagonistofanactiongametakesonp...
#
#    Runtime  Rating  No.of.Ratings
# 0      159     8.1          99114  \
# 1      167     8.2          71458
# 2      170     8.1          42372
# 3      172     5.4          42112
# 4      156     4.6          37211
#
#                                                 soup
# 0  bahubali:thebeginning inancientindia,anadventu...
# 1  baahubali2:theconclusion whenshiva,thesonofbah...
# 2  1-nenokkadine arockstarmustovercomehispsycholo...
# 3  dhoom:3 whensahir,acircusentertainertrainedinm...
# 4  ra.one whenthetitularantagonistofanactiongamet...

# %%
lists = [data['Movie'],data['Genre'],data['Overview'],data['soup']]
new_data = pd.DataFrame(lists).transpose()

# %%
new_data
# Out:
#                          Movie                    Genre
# 0        bahubali:thebeginning             action,drama  \
# 1     baahubali2:theconclusion             action,drama
# 2                1-nenokkadine          action,thriller
# 3                      dhoom:3          action,thriller
# 4                       ra.one  action,adventure,sci-fi
# ...                        ...                      ...
# 1395              maromonagadu
# 1396                  jakkanna             comedy,drama
# 1397             muvvagopaludu            drama,romance
# 1398       ninneyishtapaddaanu
# 1399                   9nelalu                    drama
#
#                                                Overview
# 0     inancientindia,anadventurousanddaringmanbecome...  \
# 1     whenshiva,thesonofbahubali,learnsabouthisherit...
# 2     arockstarmustovercomehispsychologicalinhibitio...
# 3     whensahir,acircusentertainertrainedinmagicanda...
# 4     whenthetitularantagonistofanactiongametakesonp...
# ...                                                 ...
# 1395
# 1396  themovieisaboutanattemptbysuniltheprotagonistt...
# 1397  muvvagopaluduisa1987indiantelugufilm,directedb...
# 1398  herocharan(tarun)amiddleclassfamilyguy,ischeat...
# 1399  surendramarriessavitri,anorphan.inaturnofevent...
#
#                                                    soup
# 0     bahubali:thebeginning inancientindia,anadventu...
# 1     baahubali2:theconclusion whenshiva,thesonofbah...
# 2     1-nenokkadine arockstarmustovercomehispsycholo...
# 3     dhoom:3 whensahir,acircusentertainertrainedinm...
# 4     ra.one whenthetitularantagonistofanactiongamet...
# ...                                                 ...
# 1395                                     maromonagadu
# 1396  jakkanna themovieisaboutanattemptbysunilthepro...
# 1397  muvvagopaludu muvvagopaluduisa1987indiantelugu...
# 1398  ninneyishtapaddaanu herocharan(tarun)amiddlecl...
# 1399  9nelalu surendramarriessavitri,anorphan.inatur...
#
# [1400 rows x 4 columns]

# %%
new_data[['soup']].head()
# Out:
#                                                 soup
# 0  bahubali:thebeginning inancientindia,anadventu...
# 1  baahubali2:theconclusion whenshiva,thesonofbah...
# 2  1-nenokkadine arockstarmustovercomehispsycholo...
# 3  dhoom:3 whensahir,acircusentertainertrainedinm...
# 4  ra.one whenthetitularantagonistofanactiongamet...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count1=CountVectorizer(stop_words='english')
count_matrix1=count.fit_transform(new_data['soup'])

# %%
count_matrix1.shape
# Out:
# (1400, 5434)

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix1, count_matrix1)

# %%
new_data = new_data.reset_index()
indices = pd.Series(new_data.index, index = new_data['Movie'])

# %%
new_data.head(30)
# Out:
#     index                     Movie                    Genre
# 0       0     bahubali:thebeginning             action,drama  \
# 1       1  baahubali2:theconclusion             action,drama
# 2       2             1-nenokkadine          action,thriller
# 3       3                   dhoom:3          action,thriller
# 4       4                    ra.one  action,adventure,sci-fi
# 5       5                   dhoom:2          action,thriller
# 6       6                      eega           action,fantasy
# 7       7                   krrish3            action,sci-fi
# 8       8                arjunreddy     action,drama,romance
# 9       9              rangasthalam             action,drama
# 10     10                magadheera     action,drama,fantasy
# 11     11                       war          action,thriller
# 12     12             bharatanenenu             action,drama
# 13     13                     saaho          action,thriller
# 14     14                     theri             action,drama
# 15     15                   dookudu            action,comedy
# 16     16                    pokiri          action,thriller
# 17     17                    sarkar             action,drama
# 18     18                    athadu          action,thriller
# 19     19            theghaziattack      action,thriller,war
# 20     20                    kabali       action,crime,drama
# 21     21     msg:themessengerofgod      action,comedy,drama
# 22     22                    nanban             comedy,drama
# 23     23               srimanthudu             action,drama
# 24     24              veer-vivegam          action,thriller
# 25     25                    billa2          action,thriller
# 26     26                     manam     comedy,drama,fantasy
# 27     27                 7aumarivu   action,sci-fi,thriller
# 28     28                     bigil       action,drama,sport
# 29     29               businessman             action,crime
#
#                                              Overview
# 0   inancientindia,anadventurousanddaringmanbecome...  \
# 1   whenshiva,thesonofbahubali,learnsabouthisherit...
# 2   arockstarmustovercomehispsychologicalinhibitio...
# 3   whensahir,acircusentertainertrainedinmagicanda...
# 4   whenthetitularantagonistofanactiongametakesonp...
# 5   mra,afearlessthief,stealsvaluableartefactsandt...
# 6   amurderedmanisreincarnatedasahouseflyandseekst...
# 7   krrishandhisscientistfatherhavetosavetheworlda...
# 8   arjunreddy,ashorttemperedhousesurgeongetsusedt...
# 9   thefearofhiselderbrother'sdeathstartstohauntan...
# 10  abikestuntmanrecallshispreviouslifeasawarrior,...
# 11  anindiansoldierchasesafterhismentorwhohasgoner...
# 12  bharat,anyounggraduate,becomesthec.mofandhrapr...
# 13  anundercovercopbecomesembroiledinabattlewithwa...
# 14  whenhisdaughter'slifeisendangeredbyalocalgang,...
# 15  ajay,(maheshbabu)anundercovercop,isassignedtoc...
# 16  alocalgoon'skillerinstinctsearnhimhisgirlfrien...
# 17  annribusinessmanlearnshisvotehasbeencastbysome...
# 18  agunmanforhireisframedformurder,andassumesadea...
# 19  apakistanisubmarine,ghaziplanstosecretlyattack...
# 20  returningfromprison,agedgangsterkabaliconfront...
# 21  gurujiisasocialreformerwhoworkstohelppeoplefig...
# 22  10yearsafterfinishingcollege,twobestfriendsand...
# 23  harsha,amulti-millionairewhohaseverything,stil...
# 24  aninterpolagentbetrayedbyhisfriendssetsouttota...
# 25  small-timediamondsmugglerdavidbefriendsgoa-bas...
# 26  throughreincarnation,familymembersareabletocro...
# 27  ageneticengineeringstudenttriestobringbackthes...
# 28  aformerfootballplayerstrugglestotrainawomen'sf...
# 29  suryaarrivesinmumbaitorevivethemafiaandendsupm...
#
#                                                  soup
# 0   bahubali:thebeginning inancientindia,anadventu...
# 1   baahubali2:theconclusion whenshiva,thesonofbah...
# 2   1-nenokkadine arockstarmustovercomehispsycholo...
# 3   dhoom:3 whensahir,acircusentertainertrainedinm...
# 4   ra.one whenthetitularantagonistofanactiongamet...
# 5   dhoom:2 mra,afearlessthief,stealsvaluableartef...
# 6   eega amurderedmanisreincarnatedasahouseflyands...
# 7   krrish3 krrishandhisscientistfatherhavetosavet...
# 8   arjunreddy arjunreddy,ashorttemperedhousesurge...
# 9   rangasthalam thefearofhiselderbrother'sdeathst...
# 10  magadheera abikestuntmanrecallshispreviouslife...
# 11  war anindiansoldierchasesafterhismentorwhohasg...
# 12  bharatanenenu bharat,anyounggraduate,becomesth...
# 13  saaho anundercovercopbecomesembroiledinabattle...
# 14  theri whenhisdaughter'slifeisendangeredbyaloca...
# 15  dookudu ajay,(maheshbabu)anundercovercop,isass...
# 16  pokiri alocalgoon'skillerinstinctsearnhimhisgi...
# 17  sarkar annribusinessmanlearnshisvotehasbeencas...
# 18  athadu agunmanforhireisframedformurder,andassu...
# 19  theghaziattack apakistanisubmarine,ghaziplanst...
# 20  kabali returningfromprison,agedgangsterkabalic...
# 21  msg:themessengerofgod gurujiisasocialreformerw...
# 22  nanban 10yearsafterfinishingcollege,twobestfri...
# 23  srimanthudu harsha,amulti-millionairewhohaseve...
# 24  veer-vivegam aninterpolagentbetrayedbyhisfrien...
# 25  billa2 small-timediamondsmugglerdavidbefriends...
# 26  manam throughreincarnation,familymembersareabl...
# 27  7aumarivu ageneticengineeringstudenttriestobri...
# 28  bigil aformerfootballplayerstrugglestotrainawo...
# 29  businessman suryaarrivesinmumbaitorevivethemaf...

# %%
get_recommendations('war',cosine_sim2)
# Out:
# 1243           superpolice
# 1388         gudacharino.1
# 19          theghaziattack
# 32                  spyder
# 61                 singam2
# 71                 singam3
# 108             maanagaram
# 274     nenerajunenemantri
# 442                    118
# 448              aswathama
# Name: Movie, dtype: object
